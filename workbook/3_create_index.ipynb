# %% [markdown]
# Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch
import os

es = Elasticsearch("http://127.0.0.1:9200/", basic_auth=(os.getenv("ES_USER"), os.getenv("ES_PASS")))
client_info = es.info()
print("Connected")
pprint(client_info.body)
# Out:
# elastic
# Connected
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'GD4uFQPoRiqmcsc1--6CSA',
#  'name': 'b65350ed1f64',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2026-04-01T22:08:18.783399214Z',
#              'build_flavor': 'default',
#              'build_hash': '640408e2dfd2af9fbfe5079e1575f93d8909a5f5',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '10.3.2',
#              'minimum_index_compatibility_version': '8.0.0',
#              'minimum_wire_compatibility_version': '8.19.0',
#              'number': '9.3.3'}}

# %% [markdown]
# Create Index

# %%
es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')
